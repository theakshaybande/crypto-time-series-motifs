# %% [markdown]
# # 07 Regime Effects
#
# This notebook explores what happens when the underlying behavior of the time series changes over time. Regime shifts matter because motif similarity can weaken or move when the background dynamics are no longer stationary.

# %%
from pathlib import Path
import sys

for candidate in [Path.cwd(), *Path.cwd().parents]:
    if candidate.name == "matrix_profile_lab":
        LAB_ROOT = candidate
        break
else:
    raise RuntimeError("Open this notebook from inside matrix_profile_lab.")

if str(LAB_ROOT) not in sys.path:
    sys.path.insert(0, str(LAB_ROOT))

import matplotlib.pyplot as plt

from utils.data_generators import regime_shift_series
from utils.mp_helpers import compute_matrix_profile
from utils.plotting import plot_matrix_profile

# %%
series, regime_labels = regime_shift_series(
    length=330,
    shift_points=(110, 220),
    noise=0.10,
    seed=32,
)

window = 30
mp = compute_matrix_profile(series, window=window)
fig = plot_matrix_profile(series, mp["profile"], title="Regime shifts change the profile landscape")

series_ax, profile_ax = fig.axes
for x in (110, 220):
    series_ax.axvline(x, color="black", linestyle="--", alpha=0.7)
    profile_ax.axvline(max(0, x - window // 2), color="black", linestyle="--", alpha=0.7)

fig.tight_layout()
regime_labels[:12]
